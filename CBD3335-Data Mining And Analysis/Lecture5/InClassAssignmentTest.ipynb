# %%
people = {
    'first':['Corey','Jane','John','Adam'],
    'last':['Schafer','Doe','Doe','Doe'],
    'email':['CoreyMSchafer@gmail.com','JaneDoe@email.com','JohnDoe@email.com','AdamDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe        AdamDoe@email.com

# %% [markdown]
# #### ***Sorting the dataframe records***

# %%
df.sort_values(by='last', ascending=True)
# Out:
#    first     last                    email
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe        AdamDoe@email.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
df.sort_values(by='last', ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe        AdamDoe@email.com

# %%
df.sort_values(by=['last','first'], ascending=True)  # Pass inplace value as True to make permanent changes
# Out:
#    first     last                    email
# 3   Adam      Doe        AdamDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe        AdamDoe@email.com

# %%
df.sort_values(by=['last','first'], ascending=[True,False])
# Out:
#    first     last                    email
# 2   John      Doe        JohnDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 3   Adam      Doe        AdamDoe@email.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
df.sort_index(ascending=False)
# Out:
#    first     last                    email
# 3   Adam      Doe        AdamDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
df1 = pd.read_csv('stack-overflow-developer-survey-2022/survey_results_public.csv')

# %%
df1.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df1['ConvertedCompYearly'].median()
# Out:
# 67845.0

# %%
country_grp = df1.groupby(['Country'])

# %%
country_grp

# %%
country_grp.get_group('Canada')
# Out:
#        ResponseId                                         MainBranch  \
# 1               2                     I am a developer by profession
# 22             23                     I am a developer by profession
# 32             33                        I code primarily as a hobby
# 36             37                     I am a developer by profession
# 60             61                     I am a developer by profession
# ...           ...                                                ...
# 73082       73083                              I am learning to code
# 73087       73088                              I am learning to code
# 73110       73111                     I am a developer by profession
# 73123       73124                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment      RemoteWork  \
# ...

# %%
country_grp['ConvertedCompYearly'].median().sort_values(ascending=False).head(20)
# Out:
# Country
# Monaco                                                  5000000.0
# Haiti                                                   1560600.0
# United States of America                                 145000.0
# Israel                                                   128238.0
# Barbados                                                 125001.0
# Lao People's Democratic Republic                         120000.0
# Switzerland                                              113761.0
# Ireland                                                   95979.0
# Australia                                                 93772.0
# Canada                                                    93701.0
# Iceland                                                   91920.0
# Denmark                                                   89472.0
# New Zealand                                               83633.0
# Nomadic                                                   83316.5
# ...

# %%
country_grp['ConvertedCompYearly'].mean().loc['Germany']
# Out:
# 115087.2967032967

# %%
country_grp['ConvertedCompYearly'].agg(['median','mean'])
# Out:
#                                        median          mean
# Country
# Afghanistan                           10894.0  33914.666667
# Albania                               15360.0  24895.148148
# Algeria                                7440.0  12732.888889
# Andorra                               76784.0  98003.125000
# Angola                                 3073.5   6222.750000
# ...                                       ...           ...
# Venezuela, Bolivarian Republic of...  12000.0  17079.400000
# Viet Nam                              11388.0  37707.563830
# Yemen                                 15000.0  17464.666667
# Zambia                                 6612.0   8452.000000
# Zimbabwe                              11400.0  87596.000000
#
# [180 rows x 2 columns]

# %% [markdown]
# #### ***Apply, Applymap and Map***
#
# Home Assignment

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
URL = "https://drive.google.com/file/d/1DflI7mCBPHc1Bz4DsNOJwEK6gZBs6TUL/view?usp=sharing"
Data = pd.read_csv(URL) 
Data
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="DjimUVRcyJMz64KUiuifgA">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>surv
# ...

# %%
import numpy as np
dfpeople = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(dfpeople)
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df[df['first']!='NA'].dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(how='all',axis=0)
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis='index',how='any',subset=['email','last'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
dfpeople = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(dfpeople)

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.replace('NA', np.nan, inplace=True)

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6    NaN  Missing                      NaN  Missing

# %%
df.replace('Missing', np.nan, inplace=True)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   4 non-null      object
#  1   last    4 non-null      object
#  2   email   4 non-null      object
#  3   age     4 non-null      object
# dtypes: object(4)
# memory usage: 352.0+ bytes
