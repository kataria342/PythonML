# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/13To5sxVt75i4HBEI6NU_UpeLXo2fmE-S?usp=sharing)

# %% [markdown]
# # Challenge: NLP model size
# 1. How many parameters does the BERT base cased model have (bert-base-cased)?  Use the *get_model_size function* below to help you.
# 2. If you know the number of parameters for a model, how might you be able to  determine how much memory is required when running a model inference? (Each parameter is represented as a single precision floating point number)
# 3. If you wanted to run a GPT-3 inference. How much RAM would your infrastructure require.
#
# This should take you between 5-10 minutes.

# %%
# !pip install transformers[sentencepiece]
# Out:
# Requirement already satisfied: transformers[sentencepiece] in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.30.2)
# Requirement already satisfied: filelock in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (2023.5.5)
# Requirement already satisfied: requests in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (2.28.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (4.64.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (0.1.99)
# Requirement already satisfied: protobuf<=3.20.3 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: fsspec in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers[sentencepiece]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers[sentencepiece]) (4.5.0)
# Requirement already satisfied: colorama in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>=4.27->transformers[sentencepiece]) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers[sentencepiece]) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers[sentencepiece]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers[sentencepiece]) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prabh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers[sentencepiece]) (2022.12.7)

# %%
from transformers import AutoModel
import torch

def get_model_size(checkpoint='bert-base-cased'):
  '''
  Usage: 
      checkpoint - this is NLP model with its configuration and its associated weights
      returns the size of the NLP model you want to determine
  '''
  
  model = AutoModel.from_pretrained(checkpoint)
  return sum(torch.numel(param) for param in model.parameters())

checkpoint='bert-base-cased'
print(f"The number of parameters for {checkpoint} is : {get_model_size(checkpoint)}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from transformers import AutoModel
# ----> 2 import torch
#       4 def get_model_size(checkpoint='bert-base-cased'):
#       5   '''
#       6   Usage:
#       7       checkpoint - this is NLP model with its configuration and its associated weights
#       8       returns the size of the NLP model you want to determine
#       9   '''
#
# ModuleNotFoundError: No module named 'torch'
